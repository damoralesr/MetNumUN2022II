# %% [markdown]
# <a href="https://colab.research.google.com/github/damoralesr/MetNumUN2022II/blob/main/Lab3/Linkedin_damoralesr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Perfil de LinkedIn: https://www.linkedin.com/in/david-morales-173a58251/

# %% [markdown]
# ![Linkedin.png](data:image/png;base64,...)
